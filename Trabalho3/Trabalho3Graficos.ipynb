# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(18, 6))

# Plot 1: Computational cost vs. Points Inside Hull
plt.subplot(1, 3, 1)
sns.scatterplot(data=df_performance, x='PointsInsideHull', y='ExecutionTimeMicroseconds')
plt.title('Custo Computacional vs. Pontos Dentro da Envoltória')
plt.xlabel('Pontos Dentro da Envoltória')
plt.ylabel('Tempo de Execução (Microsegundos)')

# Plot 2: Computational cost vs. Points On Hull
plt.subplot(1, 3, 2)
sns.scatterplot(data=df_performance, x='PointsOnHull', y='ExecutionTimeMicroseconds')
plt.title('Custo Computacional vs. Pontos na Envoltória')
plt.xlabel('Pontos na Envoltória')
plt.ylabel('Tempo de Execução (Microsegundos)')

# Plot 3: Computational cost vs. Ratio of PointsInsideHull to PointsOnHull
df_performance['PointsRatio'] = df_performance['PointsInsideHull'] / df_performance['PointsOnHull']
plt.subplot(1, 3, 3)
sns.scatterplot(data=df_performance, x='PointsRatio', y='ExecutionTimeMicroseconds')
plt.title('Custo Computacional vs. Razão de Pontos Dentro/Na Envoltória')
plt.xlabel('Razão de Pontos Dentro da Envoltória para Pontos na Envoltória')
plt.ylabel('Tempo de Execução (Microsegundos)')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.scatterplot(data=merged_df, x='PointDistribution', y='ExecutionTimeMilliseconds')
plt.title('Desempenho vs. Distribuição de Pontos')
plt.xlabel('Distribuição de Pontos (Pontos Dentro/Total de Pontos)')
plt.ylabel('Tempo de Execução (Milissegundos)')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))

# Subplot 1: Performance vs. Total Selected Points
plt.subplot(1, 2, 1)
sns.scatterplot(data=df_performance, x='TotalPoints', y='ExecutionTimeMicroseconds')
plt.title('Desempenho vs. Total de Pontos Selecionados')
plt.xlabel('Total de Pontos')
plt.ylabel('Tempo de Execução (Microsegundos)')

# Subplot 2: Performance vs. Point Distribution (Ratio of Inside to On Hull)
plt.subplot(1, 2, 2)
sns.scatterplot(data=df_performance, x='PointsRatio', y='ExecutionTimeMicroseconds')
plt.title('Desempenho vs. Distribuição de Pontos')
plt.xlabel('Razão de Pontos Dentro para Pontos na Envoltória')
plt.ylabel('Tempo de Execução (Microsegundos)')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(df_performance['TotalPoints'], df_performance['ExecutionTimeMicroseconds'])
plt.xlabel('Total de Pontos')
plt.ylabel('Tempo de Execução (Microsegundos)')
plt.title('Crescimento do Custo Computacional com o Total de Pontos')
plt.show()
